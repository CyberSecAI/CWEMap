# %%
import pandas as pd
import json
import csv
import os

# %%
df = pd.read_csv('data_in/KeyEntitiesAll_handchecked.csv', quoting=csv.QUOTE_ALL, escapechar='\\') # safe CSV
df
# Out:
#                  CVE               ROOTCAUSE             WEAKNESS  \
# 0      CVE-2021-0674  incorrect bounds check   out of bounds read
# 1      CVE-2021-0676  incorrect bounds check   out of bounds read
# 2      CVE-2021-0677        integer overflow   out of bounds read
# 3      CVE-2021-0678    missing bounds check  out of bounds write
# 4      CVE-2021-0679    missing bounds check    memory corruption
# ...              ...                     ...                  ...
# 4338  CVE-2022-41254                     NaN                  NaN
# 4339   CVE-2022-4169                     NaN                  NaN
# 4340  CVE-2022-41929                     NaN                  NaN
# 4341  CVE-2022-41930                     NaN                  NaN
# 4342  CVE-2022-41937                     NaN                  NaN
#
#                                                  IMPACT  \
# 0                          local information disclosure
# 1                          local information disclosure
# 2                          local information disclosure
# 3                         local escalation of privilege
# 4                         local escalation of privilege
# ...                                                 ...
# 4338  connect to attacker-specified HTTP server usin...
# 4339  update plugin and theme translation settings|i...
# 4340                           enable or disable a user
# 4341                 enable or disable any user profile
# 4342                            modify any page of wiki
#
#                              VECTOR  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# ...                             ...
# 4338                            NaN
# 4339                            NaN
# 4340                            NaN
# 4341                            NaN
# 4342  importing crafted XAR package
#
#                                                ATTACKER  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 4338             attackers with Overall/Read permission
# 4339                          unauthenticated attackers
# 4340  incorrectly authorized user with only Script r...
# 4341  any user with access to XWiki.XWikiUserProfile...
# 4342                            anyone with view access
#
#                                                 PRODUCT  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 4338                             Jenkins CONS3RT Plugin
# 4339          Theme and plugin translation for Polylang
# 4340          org.xwiki.platform:xwiki-platform-oldcore
# 4341  org.xwiki.platform:xwiki-platform-user-profile-ui
# 4342                                     XWiki Platform
#
#                                VERSION               COMPONENT
# 0                                  NaN            alac decoder
# 1                                  NaN        geniezone driver
# 2                                  NaN              ccu driver
# 3                                  NaN                  apusys
# 4                                  NaN                  apusys
# ...                                ...                     ...
# 4338                 1.0.0 and earlier                     NaN
# 4339        up to and including 3.2.16                     NaN
# 4340                               NaN  User#setDisabledStatus
# 4341                               NaN                     NaN
# 4342  before 14.6RC1, 14.6 and 13.10.8                     NaN
#
# [4343 rows x 9 columns]

# %%
matching_rows = df[df['ROOTCAUSE'] == df['WEAKNESS']]
matching_rows
# Out:
# Empty DataFrame
# Columns: [CVE, ROOTCAUSE, WEAKNESS, IMPACT, VECTOR, ATTACKER, PRODUCT, VERSION, COMPONENT]
# Index: []

# %%
matching_rows = df[df['WEAKNESS'] == df['IMPACT']]
matching_rows
# Out:
# Empty DataFrame
# Columns: [CVE, ROOTCAUSE, WEAKNESS, IMPACT, VECTOR, ATTACKER, PRODUCT, VERSION, COMPONENT]
# Index: []

# %%
matching_rows = df[df['ROOTCAUSE'].str.contains('execut|denial', case=False, na=False)]
matching_rows
# Out:
#                  CVE                              ROOTCAUSE WEAKNESS  \
# 1636  CVE-2022-29158   regular expression denial of service      NaN
# 1637  CVE-2022-29167   regular expression denial of service      NaN
# 1638  CVE-2022-29169   regular expression denial of service      NaN
# 1646  CVE-2022-31147   regular expression denial of service      NaN
# 1649  CVE-2022-31781   regular expression denial of service      NaN
# 1654  CVE-2022-34402   regular expression denial of service      NaN
# 1655  CVE-2022-34428   regular expression denial of service      NaN
# 1659   CVE-2022-3517   regular expression denial of service      NaN
# 1662  CVE-2022-36034   regular expression denial of service      NaN
# 1677  CVE-2022-40023   regular expression denial of service      NaN
# 1678  CVE-2022-40897   regular expression denial of service      NaN
# 1681  CVE-2022-42124   regular expression denial of service      NaN
# 1682  CVE-2022-42964   regular expression denial of service      NaN
# 1683  CVE-2022-42965   regular expression denial of service      NaN
# 1684  CVE-2022-42966   regular expression denial of service      NaN
# 2112  CVE-2022-26113  execution with unnecessary privileges      NaN
# 2197  CVE-2022-26113  execution with unnecessary privileges      NaN
# 2770  CVE-2022-42041                code-execution backdoor      NaN
# 2771  CVE-2022-42042                code-execution backdoor      NaN
# 3121  CVE-2022-22239  execution with unnecessary privileges      NaN
# 3408   CVE-2022-1808  execution with unnecessary privileges      NaN
#
#                                                  IMPACT  \
# 1636                                                NaN
# 1637                                  denial of service
# 1638                                  denial of service
# 1646                                                NaN
# 1649                                                NaN
# 1654                                  denial of service
# 1655                        temporary denial of service
# 1659                                  denial of service
# 1662                                                NaN
# 1677                                                NaN
# 1678                                  denial of service
# 1681                 consume excessive server resources
# 1682                                                NaN
# 1683                                                NaN
# 1684                                                NaN
# 2112                               arbitrary file write
# 2197                               arbitrary file write
# 2770                                                NaN
# 2771                                                NaN
# 3121  escalate privileges on device and potentially ...
# 3408                                                NaN
#
#                                                  VECTOR  \
# 1636                                                NaN
# 1637                                   Host HTTP header
# 1638                         specific RegularExpression
# 1646                                                NaN
# 1649                                                NaN
# 1654                                                NaN
# 1655                                                NaN
# 1659                                                NaN
# 1662                                                NaN
# 1677                                                NaN
# 1678  HTML in crafted package or custom PackageIndex...
# 1681                                    crafted payload
# 1682                                                NaN
# 1683                                                NaN
# 1684                                                NaN
# 2112                                                NaN
# 2197                                                NaN
# 2770                                                NaN
# 2771                                                NaN
# 3121                            ssh operational command
# 3408                                                NaN
#
#                                                ATTACKER  \
# 1636                              unauthenticated users
# 1637                                                NaN
# 1638                                           attacker
# 1646                                           attacker
# 1649                                                NaN
# 1654                           admin privilege attacker
# 1655              adversary with WMS group admin access
# 1659                                                NaN
# 1662                                                NaN
# 1677                                                NaN
# 1678                                   remote attackers
# 1681                                   remote attackers
# 1682                                           attacker
# 1683                                           attacker
# 1684                                           attacker
# 2112                                     local attacker
# 2197                                     local attacker
# 2770                                                NaN
# 2771                                                NaN
# 3121  locally authenticated attacker with low privil...
# 3408                                                NaN
#
#                                     PRODUCT  \
# 1636                           Apache OFBiz
# 1637                                   Hawk
# 1638                          BigBlueButton
# 1646               jQuery Validation Plugin
# 1649                        Apache Tapestry
# 1654                       Dell Wyse ThinOS
# 1655                     Dell Hybrid Client
# 1659                              minimatch
# 1662                             nitrado.js
# 1677                        Sqlalchemy mako
# 1678  Python Packaging Authority setuptools
# 1681             Liferay Portal|Liferay DXP
# 1682                               pymatgen
# 1683             snowflake-connector-python
# 1684                                   cleo
# 2112                     FortiClientWindows
# 2197                     FortiClientWindows
# 2770                                    NaN
# 2771                                    NaN
# 3121      Juniper Networks Junos OS Evolved
# 3408                        polonel/trudesk
#
#                                                 VERSION  \
# 1636                                     up to 18.12.05
# 1637                                   patched in 9.0.1
# 1638             2.2 to 2.3.19, 2.4.7, and 2.5.0-beta.2
# 1646                                    prior to 1.19.5
# 1649                                        up to 5.8.1
# 1654                                               2205
# 1655                                       prior to 1.8
# 1659                                                NaN
# 1662                                       before 0.2.5
# 1677                                       before 1.2.2
# 1678                                      before 65.5.1
# 1681  7.3.2 through 7.4.3.4|7.2 fix pack 9 through f...
# 1682                                                NaN
# 1683                                                NaN
# 1684                                                NaN
# 2112  7.0.0 through 7.0.3, 6.4.0 through 6.4.7, 6.2....
# 2197  7.0.0 through 7.0.3, 6.4.0 through 6.4.7, 6.2....
# 2770                                    d8s-file-system
# 2771                                     d8s-networking
# 3121  prior to 20.4R3-S5-EVO|21.1-EVO to 21.1R3-EVO|...
# 3408                                     prior to 1.2.3
#
#                                         COMPONENT
# 1636                                          NaN
# 1637                       Hawk.utils.parseHost()
# 1638                            bbb-html5 service
# 1646                                  url2 method
# 1649  org.apache.tapestry5.http.ContentType class
# 1654                                           UI
# 1655                                           UI
# 1659                         braceExpand function
# 1662                                          NaN
# 1677                                  Lexer class
# 1678                             package_index.py
# 1681        LayoutPageTemplateEntryUpgradeProcess
# 1682             GaussianInput.from_string method
# 1683                get_file_transfer_type method
# 1684                        Table.set_rows method
# 2112                                          NaN
# 2197                                          NaN
# 2770                                        0.1.0
# 2771                                        0.1.0
# 3121                            Management Daemon
# 3408                                          NaN
